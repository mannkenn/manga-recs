# %%
import boto3
import os
from dotenv import load_dotenv
# Connect to s3
load_dotenv()
 
s3 = boto3.client(
"s3",
aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY"),
region_name=os.getenv("AWS_DEFAULT_REGION")
)

# %%
# Target folder
folder = "../data/raw"
os.makedirs(folder, exist_ok=True)  # create folder if it doesn't exist

# File paths
manga_file_path = os.path.join(folder, 'manga_metadata.json')
user_file_path = os.path.join(folder, 'user_readdata.json')

# Download files from S3
s3.download_file(
    Bucket='manga-recs',
    Key='raw/2026-02-10/manga_metadata.json',
    Filename=manga_file_path
)

s3.download_file(
    Bucket='manga-recs',
    Key='raw/2026-02-10/user_readdata.json',
    Filename=user_file_path
)

# %% [markdown]
# # Manga metadata

# %%
import pandas as pd

# Read raw manga metadata
manga_df = pd.read_json("../data/raw/manga_metadata.json", encoding="utf-8")

# Helper: extract english title from nested title dicts or return string as-is
def extract_english_title(title):
    if isinstance(title, dict):
        # Prefer 'english' then fallback to other common keys
        extracted =  title.get('english') or title.get('romaji') or title.get('native') or None
        if extracted:
            return extracted.lower()
        return None
    elif isinstance(title, str):
            return title.lower()
    return None

# Helper: extract tag names (lowercased) from list of tag dicts
def extract_tag_names(tags):
    if isinstance(tags, list) and tags:
        names = [t.get('name') for t in tags if isinstance(t, dict) and t.get('name')]
        if names:
            return [n.lower() for n in names]

    # If tags is a single string, return it as a single-item list (lowercased)
    if isinstance(tags, str):
        return [tags.lower()]

    # Return empty list when no tags are available
    return []

# Create cleaned columns
manga_df['title_clean'] = manga_df['title'].apply(extract_english_title)
manga_df['tags_clean'] = manga_df['tags'].apply(extract_tag_names)

# Example: show original and cleaned columns
manga_df.loc[:, ['title', 'title_clean', 'tags', 'tags_clean']].head()
# Out:
#                                                title  \
# 0  {'english': 'Monster', 'romaji': 'MONSTER', 'n...
# 1  {'english': 'Berserk', 'romaji': 'Berserk', 'n...
# 2  {'english': '20th Century Boys', 'romaji': '20...
# 3  {'english': 'Yokohama Kaidashi Kikou', 'romaji...
# 4  {'english': 'Hajime no Ippo: Fighting Spirit!'...
#
#                         title_clean  \
# 0                           monster
# 1                           berserk
# 2                 20th century boys
# 3           yokohama kaidashi kikou
# 4  hajime no ippo: fighting spirit!
#
#                                                 tags  \
# 0  [{'name': 'Seinen', 'category': 'Demographic',...
# 1  [{'name': 'Tragedy', 'category': 'Theme-Drama'...
# 2  [{'name': 'Coming of Age', 'category': 'Theme-...
# 3  [{'name': 'Iyashikei', 'category': 'Theme-Slic...
# 4  [{'name': 'Boxing', 'category': 'Theme-Game-Sp...
#
#                                           tags_clean
# 0  [seinen, conspiracy, philosophy, crime, traged...
# 1  [tragedy, seinen, revenge, male protagonist, d...
# 2  [coming of age, ensemble cast, politics, seine...
# 3  [iyashikei, female protagonist, post-apocalypt...
# 4  [boxing, shounen, male protagonist, primarily ...

# %%
null_counts = manga_df.isnull().sum()
null_counts
# Out:
# title             0
# tags              0
# popularity        0
# chapters        326
# averageScore      0
# startDate         0
# endDate           0
# genres            0
# favourites        0
# meanScore         0
# isAdult           0
# id                0
# volumes         388
# description       0
# title_clean       0
# tags_clean        0
# dtype: int64

# %%
manga_df.head()
# Out:
#                                                title  \
# 0  {'english': 'Monster', 'romaji': 'MONSTER', 'n...
# 1  {'english': 'Berserk', 'romaji': 'Berserk', 'n...
# 2  {'english': '20th Century Boys', 'romaji': '20...
# 3  {'english': 'Yokohama Kaidashi Kikou', 'romaji...
# 4  {'english': 'Hajime no Ippo: Fighting Spirit!'...
#
#                                                 tags  popularity  chapters  \
# 0  [{'name': 'Seinen', 'category': 'Demographic',...       99352     162.0
# 1  [{'name': 'Tragedy', 'category': 'Theme-Drama'...      226590       NaN
# 2  [{'name': 'Coming of Age', 'category': 'Theme-...       98859     249.0
# 3  [{'name': 'Iyashikei', 'category': 'Theme-Slic...       34640     144.0
# 4  [{'name': 'Boxing', 'category': 'Theme-Game-Sp...       32860       NaN
#
#    averageScore                    startDate                        endDate  \
# 0            91  {'month': 12, 'year': 1994}    {'month': 12, 'year': 2001}
# 1            93   {'month': 8, 'year': 1989}  {'month': None, 'year': None}
# 2            88   {'month': 9, 'year': 1999}     {'month': 4, 'year': 2006}
# 3            86   {'month': 4, 'year': 1994}     {'month': 2, 'year': 2006}
# 4            87   {'month': 9, 'year': 1989}  {'month': None, 'year': None}
#
#                                               genres  favourites  meanScore  \
# 0          [Drama, Mystery, Psychological, Thriller]       10058         91
# 1  [Action, Adventure, Drama, Fantasy, Horror, Ps...       36017         93
# 2  [Drama, Mystery, Psychological, Sci-Fi, Thriller]        7780         88
# 3                            [Sci-Fi, Slice of Life]        3139         86
# 4                    [Action, Comedy, Drama, Sports]        3283         87
#
#    isAdult     id  volumes                                        description  \
# 0    False  30001     18.0  Everyone faces uncertainty at some point in th...
# 1    False  30002      NaN  His name is Guts, the Black Swordsman, a feare...
# 2    False  30003     22.0  Humanity, having faced extinction at the end o...
# 3    False  30004     14.0  Set hundreds of years in the future after an e...
# 4    False  30007      NaN  Makunouchi Ippo has been bullied his entire li...
#
#                         title_clean  \
# 0                           monster
# 1                           berserk
# 2                 20th century boys
# 3           yokohama kaidashi kikou
# 4  hajime no ippo: fighting spirit!
#
#                                           tags_clean
# 0  [seinen, conspiracy, philosophy, crime, traged...
# 1  [tragedy, seinen, revenge, male protagonist, d...
# 2  [coming of age, ensemble cast, politics, seine...
# 3  [iyashikei, female protagonist, post-apocalypt...
# 4  [boxing, shounen, male protagonist, primarily ...

# %%
# Create is_complete column as 1 (complete) or 0 (not complete)
def has_end_date(end_date):
    """Check if endDate contains None values"""
    if isinstance(end_date, dict):
        # If any value in the dict is None, return 0, otherwise 1
        return int(not any(v is None for v in end_date.values()))
    return 0  # If it's not a dict or is None itself

manga_df['is_complete'] = manga_df['endDate'].apply(has_end_date)

# %%
# Fill missing chapters with -1 to indicate unknown
manga_df['chapters'] = manga_df['chapters'].fillna(-1)
manga_df['volumes'] = manga_df['volumes'].fillna(-1)

# %%
manga_df.head()
# Out:
#                                                title  \
# 0  {'english': 'Monster', 'romaji': 'MONSTER', 'n...
# 1  {'english': 'Berserk', 'romaji': 'Berserk', 'n...
# 2  {'english': '20th Century Boys', 'romaji': '20...
# 3  {'english': 'Yokohama Kaidashi Kikou', 'romaji...
# 4  {'english': 'Hajime no Ippo: Fighting Spirit!'...
#
#                                                 tags  popularity  chapters  \
# 0  [{'name': 'Seinen', 'category': 'Demographic',...       99352     162.0
# 1  [{'name': 'Tragedy', 'category': 'Theme-Drama'...      226590      -1.0
# 2  [{'name': 'Coming of Age', 'category': 'Theme-...       98859     249.0
# 3  [{'name': 'Iyashikei', 'category': 'Theme-Slic...       34640     144.0
# 4  [{'name': 'Boxing', 'category': 'Theme-Game-Sp...       32860      -1.0
#
#    averageScore                    startDate                        endDate  \
# 0            91  {'month': 12, 'year': 1994}    {'month': 12, 'year': 2001}
# 1            93   {'month': 8, 'year': 1989}  {'month': None, 'year': None}
# 2            88   {'month': 9, 'year': 1999}     {'month': 4, 'year': 2006}
# 3            86   {'month': 4, 'year': 1994}     {'month': 2, 'year': 2006}
# 4            87   {'month': 9, 'year': 1989}  {'month': None, 'year': None}
#
#                                               genres  favourites  meanScore  \
# 0          [Drama, Mystery, Psychological, Thriller]       10058         91
# 1  [Action, Adventure, Drama, Fantasy, Horror, Ps...       36017         93
# 2  [Drama, Mystery, Psychological, Sci-Fi, Thriller]        7780         88
# 3                            [Sci-Fi, Slice of Life]        3139         86
# 4                    [Action, Comedy, Drama, Sports]        3283         87
#
#    isAdult     id  volumes                                        description  \
# 0    False  30001     18.0  Everyone faces uncertainty at some point in th...
# 1    False  30002     -1.0  His name is Guts, the Black Swordsman, a feare...
# 2    False  30003     22.0  Humanity, having faced extinction at the end o...
# 3    False  30004     14.0  Set hundreds of years in the future after an e...
# 4    False  30007     -1.0  Makunouchi Ippo has been bullied his entire li...
#
#                         title_clean  \
# 0                           monster
# 1                           berserk
# 2                 20th century boys
# 3           yokohama kaidashi kikou
# 4  hajime no ippo: fighting spirit!
#
#                                           tags_clean  is_complete
# 0  [seinen, conspiracy, philosophy, crime, traged...            1
# 1  [tragedy, seinen, revenge, male protagonist, d...            0
# 2  [coming of age, ensemble cast, politics, seine...            1
# 3  [iyashikei, female protagonist, post-apocalypt...            1
# 4  [boxing, shounen, male protagonist, primarily ...            0

# %%
def parse_date_to_datetime(date_dict):
    """Convert date dict with month and year to datetime"""
    if isinstance(date_dict, dict) and date_dict.get('month') and date_dict.get('year'):
        try:
            return pd.to_datetime(f"{int(date_dict['year'])}-{int(date_dict['month'])}-01")
        except:
            return pd.NaT
    return pd.NaT

manga_df['startDate_parsed'] = manga_df['startDate'].apply(parse_date_to_datetime)
manga_df[['startDate', 'startDate_parsed']].head(10)
# Out:
#                      startDate startDate_parsed
# 0  {'month': 12, 'year': 1994}       1994-12-01
# 1   {'month': 8, 'year': 1989}       1989-08-01
# 2   {'month': 9, 'year': 1999}       1999-09-01
# 3   {'month': 4, 'year': 1994}       1994-04-01
# 4   {'month': 9, 'year': 1989}       1989-09-01
# 5   {'month': 5, 'year': 2003}       2003-05-01
# 6   {'month': 2, 'year': 2003}       2003-02-01
# 7   {'month': 9, 'year': 1999}       1999-09-01
# 8   {'month': 8, 'year': 2001}       2001-08-01
# 9   {'month': 7, 'year': 1997}       1997-07-01

# %%
manga_df.head()
# Out:
#                                                title  \
# 0  {'english': 'Monster', 'romaji': 'MONSTER', 'n...
# 1  {'english': 'Berserk', 'romaji': 'Berserk', 'n...
# 2  {'english': '20th Century Boys', 'romaji': '20...
# 3  {'english': 'Yokohama Kaidashi Kikou', 'romaji...
# 4  {'english': 'Hajime no Ippo: Fighting Spirit!'...
#
#                                                 tags  popularity  chapters  \
# 0  [{'name': 'Seinen', 'category': 'Demographic',...       99352     162.0
# 1  [{'name': 'Tragedy', 'category': 'Theme-Drama'...      226590      -1.0
# 2  [{'name': 'Coming of Age', 'category': 'Theme-...       98859     249.0
# 3  [{'name': 'Iyashikei', 'category': 'Theme-Slic...       34640     144.0
# 4  [{'name': 'Boxing', 'category': 'Theme-Game-Sp...       32860      -1.0
#
#    averageScore                    startDate                        endDate  \
# 0            91  {'month': 12, 'year': 1994}    {'month': 12, 'year': 2001}
# 1            93   {'month': 8, 'year': 1989}  {'month': None, 'year': None}
# 2            88   {'month': 9, 'year': 1999}     {'month': 4, 'year': 2006}
# 3            86   {'month': 4, 'year': 1994}     {'month': 2, 'year': 2006}
# 4            87   {'month': 9, 'year': 1989}  {'month': None, 'year': None}
#
#                                               genres  favourites  meanScore  \
# 0          [Drama, Mystery, Psychological, Thriller]       10058         91
# 1  [Action, Adventure, Drama, Fantasy, Horror, Ps...       36017         93
# 2  [Drama, Mystery, Psychological, Sci-Fi, Thriller]        7780         88
# 3                            [Sci-Fi, Slice of Life]        3139         86
# 4                    [Action, Comedy, Drama, Sports]        3283         87
#
#    isAdult     id  volumes                                        description  \
# 0    False  30001     18.0  Everyone faces uncertainty at some point in th...
# 1    False  30002     -1.0  His name is Guts, the Black Swordsman, a feare...
# 2    False  30003     22.0  Humanity, having faced extinction at the end o...
# 3    False  30004     14.0  Set hundreds of years in the future after an e...
# 4    False  30007     -1.0  Makunouchi Ippo has been bullied his entire li...
#
#                         title_clean  \
# 0                           monster
# 1                           berserk
# 2                 20th century boys
# 3           yokohama kaidashi kikou
# 4  hajime no ippo: fighting spirit!
#
#                                           tags_clean  is_complete  \
# 0  [seinen, conspiracy, philosophy, crime, traged...            1
# 1  [tragedy, seinen, revenge, male protagonist, d...            0
# 2  [coming of age, ensemble cast, politics, seine...            1
# 3  [iyashikei, female protagonist, post-apocalypt...            1
# 4  [boxing, shounen, male protagonist, primarily ...            0
#
#   startDate_parsed
# 0       1994-12-01
# 1       1989-08-01
# 2       1999-09-01
# 3       1994-04-01
# 4       1989-09-01

# %%
manga_df
# Out:
#                                                  title  \
# 0    {'english': 'Monster', 'romaji': 'MONSTER', 'n...
# 1    {'english': 'Berserk', 'romaji': 'Berserk', 'n...
# 2    {'english': '20th Century Boys', 'romaji': '20...
# 3    {'english': 'Yokohama Kaidashi Kikou', 'romaji...
# 4    {'english': 'Hajime no Ippo: Fighting Spirit!'...
# ..                                                 ...
# 862  {'english': 'Shadow of the Supreme', 'romaji':...
# 863  {'english': 'Absolute Regression', 'romaji': '...
# 864  {'english': 'The Regressed Mercenary Has a Pla...
# 865  {'english': 'My Bias Gets on the Last Train', ...
# 866  {'english': 'Jujutsu Kaisen Modulo', 'romaji':...
#
#                                                   tags  popularity  chapters  \
# 0    [{'name': 'Seinen', 'category': 'Demographic',...       99352     162.0
# 1    [{'name': 'Tragedy', 'category': 'Theme-Drama'...      226590      -1.0
# 2    [{'name': 'Coming of Age', 'category': 'Theme-...       98859     249.0
# 3    [{'name': 'Iyashikei', 'category': 'Theme-Slic...       34640     144.0
# 4    [{'name': 'Boxing', 'category': 'Theme-Game-Sp...       32860      -1.0
# ..                                                 ...         ...       ...
# 862  [{'name': 'Male Protagonist', 'category': 'Cas...       11717      -1.0
# 863  [{'name': 'Martial Arts', 'category': 'Theme-A...       11672      -1.0
# 864  [{'name': 'Kingdom Management', 'category': 'T...       15728      -1.0
# 865  [{'name': 'Heterosexual', 'category': 'Theme-R...       11532      -1.0
# 866  [{'name': 'Shounen', 'category': 'Demographic'...       14283      -1.0
#
#      averageScore                    startDate                        endDate  \
# 0              91  {'month': 12, 'year': 1994}    {'month': 12, 'year': 2001}
# 1              93   {'month': 8, 'year': 1989}  {'month': None, 'year': None}
# 2              88   {'month': 9, 'year': 1999}     {'month': 4, 'year': 2006}
# 3              86   {'month': 4, 'year': 1994}     {'month': 2, 'year': 2006}
# 4              87   {'month': 9, 'year': 1989}  {'month': None, 'year': None}
# ..            ...                          ...                            ...
# 862            74   {'month': 8, 'year': 2024}  {'month': None, 'year': None}
# 863            80   {'month': 7, 'year': 2024}  {'month': None, 'year': None}
# 864            80   {'month': 9, 'year': 2024}  {'month': None, 'year': None}
# 865            86  {'month': 12, 'year': 2024}  {'month': None, 'year': None}
# 866            73   {'month': 9, 'year': 2025}  {'month': None, 'year': None}
#
#                                                 genres  favourites  meanScore  \
# 0            [Drama, Mystery, Psychological, Thriller]       10058         91
# 1    [Action, Adventure, Drama, Fantasy, Horror, Ps...       36017         93
# 2    [Drama, Mystery, Psychological, Sci-Fi, Thriller]        7780         88
# 3                              [Sci-Fi, Slice of Life]        3139         86
# 4                      [Action, Comedy, Drama, Sports]        3283         87
# ..                                                 ...         ...        ...
# 862                       [Action, Adventure, Fantasy]         321         75
# 863                                  [Action, Fantasy]         432         81
# 864                                  [Action, Fantasy]         616         80
# 865                                   [Drama, Romance]         834         87
# 866                     [Action, Sci-Fi, Supernatural]         390         74
#
#      isAdult      id  volumes  \
# 0      False   30001     18.0
# 1      False   30002     -1.0
# 2      False   30003     22.0
# 3      False   30004     14.0
# 4      False   30007     -1.0
# ..       ...     ...      ...
# 862    False  180890     -1.0
# 863    False  180891     -1.0
# 864    False  182066     -1.0
# 865    False  187944     -1.0
# 866    False  198372     -1.0
#
#                                            description  \
# 0    Everyone faces uncertainty at some point in th...
# 1    His name is Guts, the Black Swordsman, a feare...
# 2    Humanity, having faced extinction at the end o...
# 3    Set hundreds of years in the future after an e...
# 4    Makunouchi Ippo has been bullied his entire li...
# ..                                                 ...
# 862  Yang-Cheon Ku, born to the virtuous House of K...
# 863  The past has changed, but like a fiery comet, ...
# 864  Cecil Perdium, the Mercenary King, was killed ...
# 865  Every night, Yeo-Un takes the last train home—...
# 866  It's been 68 years since the Culling Game. In ...
#
#                             title_clean  \
# 0                               monster
# 1                               berserk
# 2                     20th century boys
# 3               yokohama kaidashi kikou
# 4      hajime no ippo: fighting spirit!
# ..                                  ...
# 862               shadow of the supreme
# 863                 absolute regression
# 864  the regressed mercenary has a plan
# 865      my bias gets on the last train
# 866               jujutsu kaisen modulo
#
#                                             tags_clean  is_complete  \
# 0    [seinen, conspiracy, philosophy, crime, traged...            1
# 1    [tragedy, seinen, revenge, male protagonist, d...            0
# 2    [coming of age, ensemble cast, politics, seine...            1
# 3    [iyashikei, female protagonist, post-apocalypt...            1
# 4    [boxing, shounen, male protagonist, primarily ...            0
# ..                                                 ...          ...
# 862  [male protagonist, martial arts, full color, f...            0
# 863  [martial arts, age regression, wuxia, revenge,...            0
# 864  [kingdom management, age regression, male prot...            0
# 865  [heterosexual, primarily adult cast, work, lon...            0
# 866  [shounen, super power, aliens, female protagon...            0
#
#     startDate_parsed
# 0         1994-12-01
# 1         1989-08-01
# 2         1999-09-01
# 3         1994-04-01
# 4         1989-09-01
# ..               ...
# 862       2024-08-01
# 863       2024-07-01
# 864       2024-09-01
# 865       2024-12-01
# 866       2025-09-01
#
# [867 rows x 18 columns]

# %% [markdown]
# # User read history

# %%
user_df = pd.read_json("../data/raw/user_readdata.json", encoding="utf-8")
user_df.head()
# Out:
#    mediaId  userId              user  progress  progressVolumes  score  notes  \
# 0    30698       1  {'name': 'Josh'}        40                6      3    NaN
# 1    33500       1  {'name': 'Josh'}         7                1      1    NaN
# 2    35178       1  {'name': 'Josh'}         6                0      2    NaN
# 3    31158       1  {'name': 'Josh'}         0                0      0    NaN
# 4    53390       1  {'name': 'Josh'}        64               10      2    NaN
#
#    priority  private  repeat    status
# 0         0    False       0    PAUSED
# 1         0    False       0    PAUSED
# 2         0    False       0    PAUSED
# 3         0    False       0  PLANNING
# 4         0    False       0   DROPPED

# %%
user_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9950 entries, 0 to 9949
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   mediaId          9950 non-null   int64
#  1   userId           9950 non-null   int64
#  2   user             9950 non-null   object
#  3   progress         9950 non-null   int64
#  4   progressVolumes  9950 non-null   int64
#  5   score            9950 non-null   int64
#  6   notes            0 non-null      float64
#  7   priority         9950 non-null   int64
#  8   private          9950 non-null   bool
#  9   repeat           9950 non-null   int64
#  10  status           9950 non-null   object
# dtypes: bool(1), float64(1), int64(7), object(2)
# memory usage: 787.2+ KB

# %%
# Extract name from user column and drop notes column
user_df['name'] = user_df['user'].apply(lambda x: x.get('name') if isinstance(x, dict) else None)
user_df = user_df.drop(columns=['notes'])
user_df.head()
# Out:
#    mediaId  userId              user  progress  progressVolumes  score  \
# 0    30698       1  {'name': 'Josh'}        40                6      3
# 1    33500       1  {'name': 'Josh'}         7                1      1
# 2    35178       1  {'name': 'Josh'}         6                0      2
# 3    31158       1  {'name': 'Josh'}         0                0      0
# 4    53390       1  {'name': 'Josh'}        64               10      2
#
#    priority  private  repeat    status  name
# 0         0    False       0    PAUSED  Josh
# 1         0    False       0    PAUSED  Josh
# 2         0    False       0    PAUSED  Josh
# 3         0    False       0  PLANNING  Josh
# 4         0    False       0   DROPPED  Josh
