# %%
import boto3
import os
from dotenv import load_dotenv
# Connect to s3
load_dotenv()
 
s3 = boto3.client(
"s3",
aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY"),
region_name=os.getenv("AWS_DEFAULT_REGION")
)

# %%
# Target folder
folder = "../data/raw"
os.makedirs(folder, exist_ok=True)  # create folder if it doesn't exist

# File paths
manga_file_path = os.path.join(folder, 'manga_metadata.json')
user_file_path = os.path.join(folder, 'user_readdata.json')

# Download files from S3
s3.download_file(
    Bucket='manga-recs',
    Key='raw/2026-02-09/manga_metadata.json',
    Filename=manga_file_path
)

s3.download_file(
    Bucket='manga-recs',
    Key='raw/2026-02-09/user_readdata.json',
    Filename=user_file_path
)

# %% [markdown]
# # Manga metadata

# %%
import pandas as pd

# Read raw manga metadata
manga_df = pd.read_json("../data/raw/manga_metadata.json", encoding="utf-8")

# Helper: extract english title from nested title dicts or return string as-is
def extract_english_title(title):
    if isinstance(title, dict):
        # Prefer 'english' then fallback to other common keys
        extracted =  title.get('english') or title.get('romaji') or title.get('native') or None
        if extracted:
            return extracted.lower()
        return None
    elif isinstance(title, str):
            return title.lower()
    return None

# Helper: extract tag names (lowercased) from list of tag dicts
def extract_tag_names(tags):
    if isinstance(tags, list) and tags:
        names = [t.get('name') for t in tags if isinstance(t, dict) and t.get('name')]
        if names:
            return [n.lower() for n in names]

    # If tags is a single string, return it as a single-item list (lowercased)
    if isinstance(tags, str):
        return [tags.lower()]

    # Return empty list when no tags are available
    return []

# Create cleaned columns
manga_df['title_clean'] = manga_df['title'].apply(extract_english_title)
manga_df['tags_clean'] = manga_df['tags'].apply(extract_tag_names)

# Example: show original and cleaned columns
manga_df.loc[:, ['title', 'title_clean', 'tags', 'tags_clean']].head()
# Out:
#                                              title  \
# 0                           {'english': 'Monster'}
# 1                           {'english': 'Berserk'}
# 2                 {'english': '20th Century Boys'}
# 3           {'english': 'Yokohama Kaidashi Kikou'}
# 4  {'english': 'Hajime no Ippo: Fighting Spirit!'}
#
#                         title_clean  \
# 0                           monster
# 1                           berserk
# 2                 20th century boys
# 3           yokohama kaidashi kikou
# 4  hajime no ippo: fighting spirit!
#
#                                                 tags  \
# 0  [{'name': 'Seinen', 'category': 'Demographic',...
# 1  [{'name': 'Tragedy', 'category': 'Theme-Drama'...
# 2  [{'name': 'Coming of Age', 'category': 'Theme-...
# 3  [{'name': 'Iyashikei', 'category': 'Theme-Slic...
# 4  [{'name': 'Boxing', 'category': 'Theme-Game-Sp...
#
#                                           tags_clean
# 0  [seinen, conspiracy, philosophy, crime, traged...
# 1  [tragedy, seinen, revenge, male protagonist, d...
# 2  [coming of age, ensemble cast, politics, seine...
# 3  [iyashikei, female protagonist, post-apocalypt...
# 4  [boxing, shounen, male protagonist, primarily ...

# %%
null_counts = manga_df.isnull().sum()
null_counts
# Out:
# title             0
# tags              0
# popularity        0
# chapters        326
# averageScore      0
# startDate         0
# endDate           0
# genres            0
# favourites        0
# meanScore         0
# isAdult           0
# id                0
# volumes         388
# description       0
# title_clean      81
# tags_clean        0
# dtype: int64

# %%
null_rows = manga_df[manga_df['title_clean'].isnull()]
null_rows
# Out:
#                  title                                               tags  \
# 79   {'english': None}  [{'name': 'Martial Arts', 'category': 'Theme-A...
# 88   {'english': None}  [{'name': 'Surreal Comedy', 'category': 'Theme...
# 95   {'english': None}  [{'name': 'Baseball', 'category': 'Theme-Game-...
# 100  {'english': None}  [{'name': 'Martial Arts', 'category': 'Theme-A...
# 104  {'english': None}  [{'name': 'Ensemble Cast', 'category': 'Cast-M...
# ..                 ...                                                ...
# 711  {'english': None}  [{'name': 'Time Skip', 'category': 'Setting-Ti...
# 751  {'english': None}  [{'name': 'Crime', 'category': 'Theme-Other', ...
# 758  {'english': None}  [{'name': 'Time Loop', 'category': 'Theme-Sci-...
# 809  {'english': None}  [{'name': 'Tsundere', 'category': 'Cast-Traits...
# 835  {'english': None}  [{'name': 'Male Protagonist', 'category': 'Cas...
#
#      popularity  chapters  averageScore                    startDate  \
# 79        14421     338.0            74  {'month': 11, 'year': 1998}
# 88        16330      89.0            80   {'month': 2, 'year': 1993}
# 95        10691     233.0            82   {'month': 6, 'year': 1998}
# 100       14325     584.0            76   {'month': 8, 'year': 2002}
# 104       10359     178.0            81  {'month': 10, 'year': 2001}
# ..          ...       ...           ...                          ...
# 711       12505       3.0            83   {'month': 2, 'year': 2021}
# 751       25997       NaN            82   {'month': 2, 'year': 2023}
# 758       10783     172.0            82   {'month': 5, 'year': 2021}
# 809       13050     106.0            73   {'month': 7, 'year': 2022}
# 835       15410       NaN            73   {'month': 5, 'year': 2023}
#
#                            endDate  \
# 79      {'month': 1, 'year': 2015}
# 88      {'month': 3, 'year': 2000}
# 95     {'month': 11, 'year': 2003}
# 100     {'month': 9, 'year': 2014}
# 104     {'month': 5, 'year': 2017}
# ..                             ...
# 711     {'month': 2, 'year': 2021}
# 751  {'month': None, 'year': None}
# 758     {'month': 7, 'year': 2024}
# 809     {'month': 8, 'year': 2023}
# 835  {'month': None, 'year': None}
#
#                                                 genres  favourites  meanScore  \
# 79              [Action, Drama, Psychological, Sports]         486         75
# 88                           [Action, Comedy, Romance]         635         80
# 95                             [Comedy, Drama, Sports]         407         83
# 100                     [Action, Comedy, Drama, Ecchi]         538         77
# 104  [Adventure, Drama, Horror, Mystery, Psychologi...         535         83
# ..                                                 ...         ...        ...
# 711                                           [Comedy]         636         83
# 751                  [Action, Adventure, Supernatural]         824         82
# 758                         [Comedy, Fantasy, Romance]         745         83
# 809            [Comedy, Ecchi, Romance, Slice of Life]         377         74
# 835                       [Action, Adventure, Fantasy]         430         74
#
#      isAdult      id  volumes  \
# 79     False   30727     34.0
# 88     False   30838     15.0
# 95     False   30915     24.0
# 100    False   30988     61.0
# 104    False   31075     35.0
# ..       ...     ...      ...
# 711    False  129574      NaN
# 751    False  138072      NaN
# 758    False  138705      NaN
# 809    False  152855      2.0
# 835    False  165287      NaN
#
#                                            description title_clean  \
# 79   At the age of sixteen Ryo Narushima was a geni...        None
# 88   Seiichirou Kitano is a naive and kind boy with...        None
# 95   Koichi Kawato is the new Japanese teacher at t...        None
# 100  The story is focused on Kenichi Shirahama, an ...        None
# 104  Scientists had predicted this disaster, and in...        None
# ..                                                 ...         ...
# 711  A Twitter comic by Ishida Sui about a gorilla ...        None
# 751  The stage is set on a volcanic island in the P...        None
# 758  Na Kang-Rim is a high school student who gener...        None
# 809  A tsundere girl getting less and less tsun day...        None
# 835  I returned to Earth after hunting demons in th...        None
#
#                                             tags_clean
# 79   [martial arts, male protagonist, anti-hero, re...
# 88   [surreal comedy, delinquents, shounen, school,...
# 95   [baseball, delinquents, coming of age, shounen...
# 100  [martial arts, shounen, delinquents, male prot...
# 104  [ensemble cast, female protagonist, survival, ...
# ..                                                 ...
# 711  [time skip, tragedy, meta, animals, philosophy...
# 751  [crime, super power, foreign, male protagonist...
# 758  [time loop, female harem, school, full color, ...
# 809  [tsundere, heterosexual, female protagonist, p...
# 835  [male protagonist, full color, gods, demons, s...
#
# [81 rows x 16 columns]

# %% [markdown]
# # User read history

# %%
user_df = pd.read_json("../data/raw/user_readdata.json", encoding="utf-8")
user_df.head()
# Out:
#    mediaId  userId              user  progress  progressVolumes  score  notes  \
# 0    30698       1  {'name': 'Josh'}        40                6      3    NaN
# 1    33500       1  {'name': 'Josh'}         7                1      1    NaN
# 2    35178       1  {'name': 'Josh'}         6                0      2    NaN
# 3    31158       1  {'name': 'Josh'}         0                0      0    NaN
# 4    53390       1  {'name': 'Josh'}        64               10      2    NaN
#
#    priority  private  repeat    status
# 0         0    False       0    PAUSED
# 1         0    False       0    PAUSED
# 2         0    False       0    PAUSED
# 3         0    False       0  PLANNING
# 4         0    False       0   DROPPED
