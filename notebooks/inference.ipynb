# %%
import pandas as pd
import joblib
from pathlib import Path
from manga_recs.data_engineering.load.s3 import s3_load

# Paths
MODEL_PATH = s3_load("cosine_sim.pkl", bucket="manga-recs", status="models")
METADATA_PATH = s3_load("cleaned_manga_metadata.parquet", bucket="manga-recs", status="cleaned")

# Load similarity matrix + metadata
SIM_MATRIX = joblib.load(MODEL_PATH)
METADATA = pd.read_parquet(METADATA_PATH)

def get_top_n_recommendations(manga_id, top_n=5):

    # Get row index for the given manga_id
    similarities = SIM_MATRIX.loc[manga_id]  # Ensure manga_id is valid

    # Get top N most similar
    top_similarities = similarities.sort_values(ascending=False).head(top_n)

    # Get the corresponding metadata for these manga IDs
    recs = METADATA[METADATA['id'].isin(top_similarities.index)][['id', 'title', 'description', 'tags']]

    # Merge similarity scores into metadata
    recs = recs.set_index('id')  # set 'id' as index to match top_similarities
    recs = recs.join(top_similarities.rename("similarity"))  # add similarity column
    recs['similarity'] = recs['similarity'].round(2)  # round similarity for better readability

    return recs.reset_index().to_dict(orient='records')

# test
if __name__ == "__main__":
    recommendations = get_top_n_recommendations(manga_id=30002, top_n=5)
    print(recommendations)
# Out:
# Downloaded cosine_sim.pkl from s3://manga-recs/models/2026-02-18/cosine_sim.pkl
# Downloaded cleaned_manga_metadata.parquet from s3://manga-recs/cleaned/2026-02-15/cleaned_manga_metadata.parquet
# [{'id': 30013, 'title': 'one piece', 'description': 'As a child, Monkey D. Luffy was inspired to become a pirate by listening to the tales of the buccaneer "Red-Haired" Shanks. But his life changed when Luffy accidentally ate the Gum-Gum Devil Fruit and gained the power to stretch like rubber...at the cost of never being able to swim again! Years later, still vowing to become the king of the pirates, Luffy sets out on his adventure...one guy alone in a rowboat, in search of the legendary "One Piece," said to be the greatest treasure in the world...\n<br><br>\n(Source: VIZ Media)', 'tags': array(['pirates', 'travel', 'found family', 'shounen', 'ensemble cast',
#        'super power', 'ships', 'tragedy', 'politics', 'fugitive', 'crime',
#        'male protagonist', 'conspiracy', 'military', 'slapstick', 'war',
#        'terrorism', 'time skip', 'lost civilization', 'anachronism',
#        'slavery', 'post-apocalyptic', 'primarily adult cast',
#        'cultivation', 'gods', 'swordplay', 'mythology', 'religion',
#        'animals', 'environmental', 'gangs', 'espionage', 'anti-hero',
#        'prison', 'anthropomorphism', 'primarily male cast', 'skeleton',
#        'samurai', 'cyborg', 'henshin', 'adoption', 'meta', 'food',
#        'medicine', 'robots', 'mermaid', 'assassins', 'drugs', 'guns',
#        'battle royale', 'revenge', 'board game', 'dragons', 'amnesia',
#        'monster girl', 'desert', 'surreal comedy', 'oiran',
#        'time manipulation', 'kemonomimi', 'demons', 'memory manipulation',
#        'ninja', 'transgender', 'zombie', 'trains', 'aliens', 'clone',
#        'centaur', 'dinosaurs', 'gender bending', 'angels',
#        'shapeshifting', 'bar', 'female protagonist', 'body swapping',
#        'curses', 'arranged marriage', 'artificial intelligence',
#        'episodic'], dtype=object), 'similarity': 0.55}, {'id': 30642, 'title': 'vinland saga', 'description': "As a child, Thorfinn sat at the feet of the great Leif Ericson and thrilled to wild tales of a land far to the west. But his youthful fantasies were shattered by a mercenary raid. Raised by the Vikings who murdered his father, Thorfinn became a terrifying warrior, forever seeking to kill the band's leader, Askeladd, and avenge his father. Sustaining Thorfinn through his ordeal are his pride in his family and his dreams of a fertile westward land, a land without war or slavery … the land Leif called Vinland.\n<br><br>\n(Source: Kodansha USA)\n<br><br>\n<i>Notes:<br>\n- Won the Grand Prize at the Japan Media Arts Festival in 2009.<br>\n- Winner of the 36th Kodansha Manga Award in the General category in 2012.</i>", 'tags': array(['rehabilitation', 'historical', 'coming of age', 'vikings',
#        'foreign', 'philosophy', 'seinen', 'male protagonist', 'war',
#        'revenge', 'tragedy', 'travel', 'found family',
#        'primarily adult cast', 'primarily male cast', 'slavery', 'gore',
#        'time skip', 'swordplay', 'ships', 'politics', 'medieval', 'rural',
#        'parenthood', 'class struggle', 'anti-hero', 'agriculture',
#        'pirates', 'environmental', 'religion', 'indigenous cultures',
#        'achronological order', 'adoption', 'language barrier',
#        'mythology', 'nudity', 'archery', 'wilderness', 'tomboy',
#        'transgender', 'lgbtq+ themes'], dtype=object), 'similarity': 0.62}, {'id': 30656, 'title': 'vagabond', 'description': "At seventeen years of age, Miyamoto Musashi--still known by his childhood name, Shinmen Takezo--was a wild young brute just setting out along the way of the sword.\n<br><br>\nIn the aftermath of the epic Battle of Sekigahara, Takezo finds himself a fugitive survivor on the losing side of the war. Takezo's vicious nature has made him an outcast even in his own village, and he is hunted down like an animal. At this crucial crossroads in Takezo's life, an eccentric monk and a childhood friend are the only ones who can help him find his way.<br><br>(Source: VIZ Media)", 'tags': array(['samurai', 'swordplay', 'seinen', 'historical', 'philosophy',
#        'travel', 'coming of age', 'male protagonist', 'tragedy',
#        'martial arts', 'disability', 'survival', 'cultivation',
#        'biographical', 'gore', 'rural', 'war', 'heterosexual',
#        'outdoor activities', 'ghost', 'agriculture', 'classic literature',
#        'language barrier', 'fugitive', 'nudity', 'afterlife', 'rape'],
#       dtype=object), 'similarity': 0.59}, {'id': 46765, 'title': 'kingdom', 'description': 'Xin is a war orphan in a poor village in the kingdom of Qin. He has big dreams of becoming a great general, and when his best friend’s life is cut short by political machinations, Xin sets off to find a deposed ruler and help restore his place on the throne, while working his way up through the ranks of the Qin kingdom’s army to do what no one has ever done before—unify China.\n<br><br>\n(Source: VIZ Media)', 'tags': array(['military', 'historical', 'war', 'ancient china', 'politics',
#        'royal affairs', 'male protagonist', 'seinen', 'coming of age',
#        'swordplay', 'tragedy', 'foreign', 'heterosexual', 'gore',
#        'primarily male cast', 'fugitive', 'conspiracy', 'body horror',
#        'archery', 'ensemble cast', 'spearplay', 'time skip', 'assassins',
#        'torture', 'crossdressing', 'nudity', 'magic'], dtype=object), 'similarity': 0.57}, {'id': 53390, 'title': 'attack on titan', 'description': "In this post-apocalyptic sci-fi story, humanity has been devastated by the bizarre, giant humanoids known as the Titans. Little is known about where they came from or why they are bent on consuming mankind. Seemingly unintelligent, they have roamed the world for years, killing everyone they see. For the past century, what's left of man has hidden in a giant, three-walled city. People believe their 50-meter-high walls will protect them from the Titans, but the sudden appearance of an immense Titan is about to change everything.\n<br><br>\n(Source: Kodansha USA)\n<br><br>\n<i>Note: Includes two extra chapters.</i>", 'tags': array(['dystopian', 'anti-hero', 'war', 'philosophy', 'tragedy',
#        'military', 'conspiracy', 'survival', 'kaiju', 'shapeshifting',
#        'memory manipulation', 'politics', 'revenge', 'henshin',
#        'male protagonist', 'monster boy', 'terrorism', 'post-apocalyptic',
#        'super power', 'gore', 'time manipulation', 'body horror',
#        'ensemble cast', 'cosmic horror', 'time skip', 'cannibalism',
#        'coming of age', 'slavery', 'swordplay', 'torture', 'shounen',
#        'espionage', 'mythology', 'medieval', 'amnesia', 'tsundere',
#        'kuudere', 'class struggle', 'disability', 'cult',
#        'dissociative identities', 'drugs', 'achronological order',
#        'transgender', 'religion', 'heterosexual', 'reincarnation',
#        'suicide', 'baseball', 'acrobatics', 'primarily adult cast',
#        'yuri'], dtype=object), 'similarity': 0.6}]
